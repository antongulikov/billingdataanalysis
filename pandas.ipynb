# %%
import pandas
import numpy

# %%
data = pandas.read_table('./petrov_data.csv', skiprows=10 ,nrows=10000, sep=",")

# %%
data
# Out:
#     20.10.2015 08.59.42        Телефония входящая  219499701225  7811  \
# 0   20.10.2015 09.08.48  Пакетная передача данных  219508190407  7811
# 1   20.10.2015 09.22.11  Пакетная передача данных  219510597242  7811
# 2   20.10.2015 09.24.06  Пакетная передача данных  219510491015  7811
# 3   20.10.2015 10.08.48  Пакетная передача данных  219516909739  7811
# 4   20.10.2015 11.08.48  Пакетная передача данных  219525832424  7811
# 5   20.10.2015 12.05.06       Телефония исходящая  219523884799  7811
# 6   20.10.2015 12.08.48  Пакетная передача данных  219533851988  7811
# 7   20.10.2015 13.08.48  Пакетная передача данных  219542052332  7811
# 8   20.10.2015 13.19.05        Телефония входящая  219541835460  7811
# 9   20.10.2015 14.08.48  Пакетная передача данных  219549703337  7811
# 10  20.10.2015 14.24.06  Пакетная передача данных  219552189269  7811
# 11  20.10.2015 15.08.48  Пакетная передача данных  219558486367  7811
# ...

# %%
for x in tmp.columns:
    print(x)
# Out:
# time
# type
# call_id
# lac
# code

# %%
type(tmp)
# Out:
# pandas.core.frame.DataFrame
